# %% [markdown]
# <a href="https://colab.research.google.com/github/Eshwar260/RL-LAB/blob/main/RL_Lab_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium

# %%
import gymnasium as gym
import random

# %% [markdown]
# **Part-A Random Agent on CliffWalking**

# %%
import gymnasium as gym
import random

# Create environment
env = gym.make("CliffWalking-v1")

# Number of episodes
episodes = 10

rewards = []

for episode in range(1, episodes + 1):

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    terminated = False
    truncated = False

    while not (terminated or truncated):

        # Identify available actions
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        # Update state
        state = next_state

        # Add reward
        total_reward += reward

    rewards.append(total_reward)

    print(f"Episode {episode}: Total Reward = {total_reward}")

# Calculate average reward
average_reward = sum(rewards) / len(rewards)

print("\nCliffWalking Results")
print("--------------------")
print("Total Episodes:", episodes)
print("Average Reward:", average_reward)

env.close()
# Out:
# Episode 1: Total Reward = -49446
# Episode 2: Total Reward = -1500
# Episode 3: Total Reward = -31582
# Episode 4: Total Reward = -164915
# Episode 5: Total Reward = -129676
# Episode 6: Total Reward = -100924
# Episode 7: Total Reward = -204857
# Episode 8: Total Reward = -79519
# Episode 9: Total Reward = -143737
# Episode 10: Total Reward = -1014
#
# CliffWalking Results
# --------------------
# Total Episodes: 10
# Average Reward: -90717.0

# %% [markdown]
# **Part B — Random Agent on Taxi**

# %%
import gymnasium as gym
import random

# Create environment
env = gym.make("Taxi-v4")

# Number of episodes
episodes = 10

rewards = []

for episode in range(1, episodes + 1):

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    terminated = False
    truncated = False

    while not (terminated or truncated):

        # Identify available actions
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        # Update state
        state = next_state

        # Add reward
        total_reward += reward

    rewards.append(total_reward)

    print(f"Episode {episode}: Total Reward = {total_reward}")

# Calculate average reward
average_reward = sum(rewards) / len(rewards)

print("\nTaxi Results")
print("------------")
print("Total Episodes:", episodes)
print("Average Reward:", average_reward)

env.close()
# Out:
# Episode 1: Total Reward = -740
# Episode 2: Total Reward = -785
# Episode 3: Total Reward = -839
# Episode 4: Total Reward = -812
# Episode 5: Total Reward = -695
# Episode 6: Total Reward = -893
# Episode 7: Total Reward = -848
# Episode 8: Total Reward = -767
# Episode 9: Total Reward = -830
# Episode 10: Total Reward = -722
#
# Taxi Results
# ------------
# Total Episodes: 10
# Average Reward: -793.1
